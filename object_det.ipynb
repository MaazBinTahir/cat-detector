# %%
# Installing imutils
# !pip install imutils

# Importing libraries
import cv2
from imutils import contours
import matplotlib.pyplot as plt

# Reading the image
image = cv2.imread('cat1.jpg')

# Creating copy
original = image.copy()

# Converting into Grayscale
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# Adding blur for noise reduction
blur = cv2.GaussianBlur(gray, (3,3), 0)

# Thresholding
thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Finding contours
cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = cnts[0] if len(cnts) == 2 else print("No Contour Found")

# Sorting Contours
(cnts, _) = contours.sort_contours(cnts, method="left-to-right")
largest_contour = cnts[0]

# Creating Bounding Box
x,y,w,h = cv2.boundingRect(largest_contour)
cv2.rectangle(image, (x, y), (x + w, y + h), (255,100,12), 3)

# Plotting image
plt.imshow(image)

# %%
# NOTE: only gives better results when imaage with white backgroud is used.
